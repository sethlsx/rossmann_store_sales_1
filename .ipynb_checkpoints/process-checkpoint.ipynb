# %% [markdown]
# # Rossmann Store Sales项目的项目文件

# %% [markdown]
# ## 载入必要的库
# 首先，需要载入必要的库。

# %%
import numpy as np
import xgboost as xgb
import pandas as pd
from IPython.display import display #方便对数据进行可视化

# %% [markdown]
# ## 数据预处理
# ### 数据读入
# 然后，我们需要读入数据。

# %%
# 导入训练数据
train_data = pd.read_csv(
    "train.csv", 
    low_memory=False)

store_features = pd.read_csv("store.csv")
# 导入测试数据
test_data = pd.read_csv("test.csv")

# 显示头5条记录

display(train_data.head(n=5))
display(store_features.head(n=5))
display(test_data.head(n=5))
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# ...

# %% [markdown]
# 然后我们需要将train_data与store_feature按照商店编号（Store这个特征域）融合到一个数据集中。对于test数据也做同样处理。

# %%
#融合
train_data = pd.merge(train_data, store_features, on = 'Store')
test_data = pd.merge(test_data, store_features, on = 'Store')
#显示头5条记录
display(train_data.head(n=5))
display(test_data.head(n=5))
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %% [markdown]
# 观察test.csv的数据可以发现，Date这个数据都是2015年8月1日之后的，而train.csv的日期最晚到2015年7月31日，而Date数据的类型是字符串，相当于分类数据，直接使用数据将导致test中的Date数据是train中没有出现过的分类，因此要么转换成数值数据，要么把日期拆分成年，月，日3个分类数据。这里将字符串的时间转化为时间戳数值数据。

# %%
#将字符串转化为时间戳数值
train_data['Date'] = pd.to_datetime(train_data['Date'])
test_data['Date'] = pd.to_datetime(test_data['Date'])

#然后再把时间戳数值转化为浮点值

train_data['Date'] = pd.to_numeric(train_data['Date'], downcast = 'float')
test_data['Date'] = pd.to_numeric(test_data['Date'], downcast = 'float')

#继续通过显示头5条数据来验证转化情况

display(train_data.head(n=5))
print(type(train_data['Date'][1])) #检验一下转化之后的数据类型
print(train_data['Date'][1]-train_data['Date'][2])
display(test_data.head(n=5))
# Out:
#    Store  DayOfWeek          Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  1.438301e+18   5263        555     1      1            0
# 1      1          4  1.438214e+18   5020        546     1      1            0
# 2      1          3  1.438128e+18   4782        523     1      1            0
# 3      1          2  1.438042e+18   5011        560     1      1            0
# 4      1          1  1.437955e+18   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %% [markdown]
# 可以看到转换后的数值极其的大，我们需要将其归一化

# %%
start_date = min(train_data['Date'])
end_date = max(test_data['Date'])
train_data['Date'] = (train_data['Date'] - start_date)/(end_date - start_date)
test_data['Date'] = (test_data['Date'] - start_date)/(end_date - start_date)
#看一下转化后的结果
display(train_data.head(n=5))
display(test_data.head(n=5))
# Out:
#    Store  DayOfWeek      Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  0.951466   5263        555     1      1            0
# 1      1          4  0.950454   5020        546     1      1            0
# 2      1          3  0.949443   4782        523     1      1            0
# 3      1          2  0.948432   5011        560     1      1            0
# 4      1          1  0.947421   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# ...

# %% [markdown]
# 观察可以看到，测试集中是没有customer这个特征的，所以在训练集中需要去掉这个特征

# %%
train_data = train_data.drop('Customers', axis = 1)

# %% [markdown]
# 下面把数据切分成特征和标签

# %%
sales = train_data['Sales']
features = train_data.drop('Sales', axis = 1)

display(sales.head(n=1))
display(features.head(n=1))
# Out:
# 0    5263
# Name: Sales, dtype: int64
#    Store  DayOfWeek      Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0      1          5  0.951466     1      1            0              1
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
#
#   PromoInterval
# 0           NaN

# %% [markdown]
# 需要把一些不规范的数据处理一下

# %%
# 需要把NA/NAN的数据转化成0
features.fillna(0, inplace = True)
test_data.fillna(0, inplace =True)

display(features.head(n=5))
display(test_data.head(n=5))
# Out:
#    Store  DayOfWeek      Date  Open  Promo StateHoliday  SchoolHoliday  \
# 0      1          5  0.951466     1      1            0              1
# 1      1          4  0.950454     1      1            0              1
# 2      1          3  0.949443     1      1            0              1
# 3      1          2  0.948432     1      1            0              1
# 4      1          1  0.947421     1      1            0              1
#
#   StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0         c          a               1270.0                        9.0
# 1         c          a               1270.0                        9.0
# 2         c          a               1270.0                        9.0
# 3         c          a               1270.0                        9.0
# 4         c          a               1270.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
# 对字符串特征进行独热编码
category = ['StoreType', 'Assortment', 'PromoInterval', 'StateHoliday']

features_pd = pd.get_dummies(features, columns = category)
test_data_pd = pd.get_dummies(test_data, columns = category)

display(features_pd.head(n=5))
display(test_data_pd.head(n=5))
# Out:
#    Store  DayOfWeek      Date  Open  Promo  SchoolHoliday  \
# 0      1          5  0.951466     1      1              1
# 1      1          4  0.950454     1      1              1
# 2      1          3  0.949443     1      1              1
# 3      1          2  0.948432     1      1              1
# 4      1          1  0.947421     1      1              1
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0               1270.0                        9.0                    2008.0
# 1               1270.0                        9.0                    2008.0
# 2               1270.0                        9.0                    2008.0
# 3               1270.0                        9.0                    2008.0
# 4               1270.0                        9.0                    2008.0
#
#    Promo2       ...        Assortment_b  Assortment_c  PromoInterval_0  \
# 0       0       ...                   0             0                1
# ...

# %% [markdown]
# 可视化可以看到在训练集独热编码后为27列，而测试集只有26列，去掉训练集没有的Id，只有25列，可见测试集中比训练集少了一些类别，需要改变一下编码方式

# %%
#首先将训练集和测试集合并，然后统一独热编码，然后再拆分为训练集和测试集
features_test = test_data.drop('Id', axis = 1)
data_merge = pd.concat([features, features_test], ignore_index = True)
data_merge_pd = pd.get_dummies(data_merge, columns = category)
display(data_merge_pd.head(n=5))

#拆分
print(features.shape)
print(features_test.shape)
features_pd = data_merge_pd[0:features.shape[0]]
features_test_pd = data_merge_pd[features.shape[0]:data_merge_pd.shape[0]]
print(features_pd.shape)
print(features_test_pd.shape)

display(features_pd.head(n=5))
display(features_test_pd.head(n=5))
# Out:
#    Store  DayOfWeek      Date  Open  Promo  SchoolHoliday  \
# 0      1          5  0.951466   1.0      1              1
# 1      1          4  0.950454   1.0      1              1
# 2      1          3  0.949443   1.0      1              1
# 3      1          2  0.948432   1.0      1              1
# 4      1          1  0.947421   1.0      1              1
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0               1270.0                        9.0                    2008.0
# 1               1270.0                        9.0                    2008.0
# 2               1270.0                        9.0                    2008.0
# 3               1270.0                        9.0                    2008.0
# 4               1270.0                        9.0                    2008.0
#
#    Promo2       ...        Assortment_b  Assortment_c  PromoInterval_0  \
# 0       0       ...                   0             0                1
# ...

# %% [markdown]
# 下面切分数据，把数据切分成训练集和验证集

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    features_pd, sales, test_size = 0.2, random_state = 1)

display(X_train.head(n=5))
display(y_train.head(n=5))
# Out:
#         Store  DayOfWeek      Date  Open  Promo  SchoolHoliday  \
# 903560    991          2  0.339737   1.0      1              0
# 509452    559          5  0.385238   1.0      0              0
# 570376    626          5  0.739130   1.0      0              1
# 264963    292          5  0.165823   1.0      0              0
# 961639   1055          2  0.898887   1.0      0              0
#
#         CompetitionDistance  CompetitionOpenSinceMonth  \
# 903560               1010.0                        0.0
# 509452               3910.0                       11.0
# 570376              10740.0                       11.0
# 264963               1100.0                        6.0
# 961639               1980.0                        4.0
#
#         CompetitionOpenSinceYear  Promo2       ...        Assortment_b  \
# 903560                       0.0       0       ...                   0
# 509452                    2006.0       1       ...                   0
# ...

# %% [markdown]
# 下面引入模型
#
# 对xgboost的使用主要参考了以下资源：
# - https://blog.csdn.net/zc02051126/article/details/46771793
# - https://blog.csdn.net/u010657489/article/details/51952785
# - https://www.analyticsvidhya.com/blog/2016/02/complete-guide-parameter-tuning-gradient-boosting-gbm-python/
# - https://blog.csdn.net/u011630575/article/details/79418138
# - https://datascience.stackexchange.com/questions/12799/pandas-dataframe-to-dmatrix

# %%
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

# %% [markdown]
# 下面要对模型进行训练

# %%
#首先设定参数

param = {'max_depth': 5, 'eta': 0.3, 'silent': 0, 'objective': 'reg:linear'}

#设定迭代次数

num_round = 100

#训练模型，记录训练时间
#定义一个函数，便于后期进行参数调优反复调用

import time
def train(param, dtrain, num_round):
    train_time = time.clock()

    bst = xgb.train(param, dtrain, num_round, feval)

    train_time = time.clock() - train_time

    print('The training time of the model is: {:.0f}s'.format(train_time))
    
    return bst

model = train(param, dtrain, num_round)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2fcbb3a9d004> in <module>()
#      22     return bst
#      23
# ---> 24 model = train(param, dtrain, num_round)
#
# <ipython-input-25-2fcbb3a9d004> in train(param, dtrain, num_round, feval)
#      14     train_time = time.clock()
#      15
# ---> 16     bst = xgb.train(param, dtrain, num_round)
#      17
#      18     train_time = time.clock() - train_time
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# ...

# %%
#需要定义一个函数来计算均⽅方根百分⽐比误差RMSPE

def rmspe(y, y_hat):
    #由于有yi=0的情况，直接计算会得出无穷大的结果，所以需要处理一下
    #定义一个y_rev来表示y的倒数，y为0时y_rev也赋值为0（因为在项目中提到“ Any day and store with 0 sales is ignored in scoring.“）
    y_rev = np.zeros(y.shape, dtype = float)
    n_zero = y != 0
    y_rev[n_zero] = 1./y[n_zero]
    rmspe = np.sqrt(np.mean(((y - y_hat)*y_rev)**2))
    return rmspe

#定义一个打分函数
def score(bst, dval):
    y_pred = bst.predict(dval)
#print(y_pred)
    y_val = dval.get_label()
    score = rmspe(y_val, y_pred)
#print(score)
    print('The rmspe of the model on validation data set is {:.6f}'.format(score))
    pass

#来看看验证集上的结果
score(model, dval)
# Out:
# The rmspe of the model on validation data set is 744.244328

# %% [markdown]
# 可以看到这个得分不高，所以下面进行参数调优，主要参考以下文章
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %% [markdown]
# 尝试增加最大深度和迭代次数，并增加学习率

# %%
#首先设定参数

param = {'max_depth': 10, 'eta': 0.3, 'silent': 0, 'objective': 'reg:linear'}

#设定迭代次数

num_round = 300
model_op1 = train(param, dtrain, num_round)
score(model_op1, dval)
# Out:
# The training time of the model is: 536s
# The rmspe of the model on validation data set is 0.120045

# %% [markdown]
# 这个结果还不错！在测试集上跑跑看。

# %% [markdown]
# 下面进行测试

# %%
dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op1.predict(dtest)
submission = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission.to_csv('xgboost_submit.csv', index = False)

# %% [markdown]
# 上传得分仅0.40288，出现了过拟合现象，下面进行调整
#
# 首先观察预测值，发现出现负值的预测值，且均出现在商店未开门的状态下，所以返回前面的特征工程，仅用商店开门的数据进行训练。

# %%
train_data_op = train_data[train_data['Open'] != 0]
#切分
sales_op = train_data_op['Sales']
features_op = train_data_op.drop('Sales', axis = 1)
#处理
# 需要把NA/NAN的数据转化成0
features_op.fillna(0, inplace = True)

#首先将训练集和测试集合并，然后统一独热编码，然后再拆分为训练集和测试集
data_merge_op = pd.concat([features_op, features_test], ignore_index = True)
data_merge_pd_op = pd.get_dummies(data_merge_op, columns = category)

#拆分
features_pd_op = data_merge_pd_op[0:features_op.shape[0]]
features_test_pd = data_merge_pd[features_op.shape[0]:data_merge_pd_op.shape[0]]

X_train_op, X_val_op, y_train_op, y_val_op = train_test_split(
    features_pd_op, sales_op, test_size = 0.2, random_state = 1)

dtrain = xgb.DMatrix(X_train_op, label = y_train_op)
dval = xgb.DMatrix(X_val_op, label = y_val_op)

# %% [markdown]
# 重新训练

# %%
#首先设定参数

param = {'max_depth': 10, 'eta': 0.3, 'silent': 0, 'objective': 'reg:linear'}

#设定迭代次数

num_round = 300
model_op2 = train(param, dtrain, num_round)
score(model_op2, dval)
# Out:
# The training time of the model is: 401s
# The rmspe of the model on validation data set is 0.125018

# %% [markdown]
# 在测试集上跑跑看

# %%
dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op2.predict(dtest)
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op_submit.csv', index = False)

# %% [markdown]
# 发现依然有负值，先提交看看评分。评分为0.60213，变差了：（

# %% [markdown]
# 增加参数，解决过拟合的问题

# %%
#自定义一个评价函数

def rmspe_feval(dy, y_hat):
    y = dy.get_label()
    rmspe_score = rmspe(y, y_hat)
    return 'rmspe', rmspe_score

#设定参数，减小eta，增强鲁棒性，添加subsample参数，减小过拟合

param = {'max_depth': 10, 'eta': 0.2, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#设定迭代次数

num_round = 300

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
#重新定义训练函数
def train_op(param, dtrain, num_round, feval_c):
    train_time = time.clock()

    model = xgb.train(param, dtrain, num_round, feval = feval_c)

    train_time = time.clock() - train_time

    print('The training time of the model is: {:.0f}s'.format(train_time))
    
    return model
model_op3 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op3, dval)
# Out:
# The training time of the model is: 652s
# The rmspe of the model on validation data set is 0.122423

# %% [markdown]
# 结果还行，训练时间偏长，用测试集试试

# %%
dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op3.predict(dtest)
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op3_submit.csv', index = False)

# %% [markdown]
# 得分0.68340，更差了。。。。

# %% [markdown]
#     此前在开题报告的审阅中提到sales是倾斜分布的，考虑到预测出现负值，准备对sales进行log处理，这里先可视化一下

# %%
train_data.hist(column = 'Sales')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x131a9ca20>]],
#       dtype=object)

# %%
#下面将sales做log处理

sales_log = np.log(train_data['Sales'] + 1) #+1是为了避免log（0）的情况同时使得数据从0开始

sales_log.plot.hist()


X_train, X_val, y_train, y_val = train_test_split(
    features_pd, sales_log, test_size = 0.2, random_state = 1)

# %%
#设定参数，减小eta，增强鲁棒性，添加subsample参数，减小过拟合

param = {'max_depth': 10, 'eta': 0.2, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#设定迭代次数

num_round = 300

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
#重新定义训练函数
def train_op(param, dtrain, num_round, feval_c):
    train_time = time.clock()

    model = xgb.train(param, dtrain, num_round, feval = feval_c)

    train_time = time.clock() - train_time

    print('The training time of the model is: {:.0f}s'.format(train_time))
    
    return model
model_op4 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op4, dval)
# Out:
# The training time of the model is: 658s
# The rmspe of the model on validation data set is 0.011078

# %% [markdown]
# 然后继续在测试集上跑，这里要注意把对数值转化回去

# %%
dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op4.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op4_submit.csv', index = False)

# %% [markdown]
# 继续上传。。。得分0.68083......应该是比较严重的过拟合

# %%
#设定参数，减小max_depth，减小eta

param = {'max_depth': 5, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#设定迭代次数

num_round = 300

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op4 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op4, dval)


dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op4.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op4_submit.csv', index = False)
# Out:
# The training time of the model is: 309s
# The rmspe of the model on validation data set is 0.022561

# %%
#假如把closed 的商店手动设为0呢？

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op4.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op4_submit.csv', index = False)

# %% [markdown]
# 不行，还要继续调参数

# %%
#设定参数，减小max_depth，减小eta

param = {'max_depth': 5, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op5 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op5, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op5.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op5_submit.csv', index = False)
# Out:
# The training time of the model is: 104s
# The rmspe of the model on validation data set is 0.031158

# %% [markdown]
# no good, go on

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op6 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op6, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op6.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op6_submit.csv', index = False)
# Out:
# The training time of the model is: 62s
# The rmspe of the model on validation data set is 0.035770

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 50

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op7 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op7, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op7.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op7_submit.csv', index = False)
# Out:
# The training time of the model is: 31s
# The rmspe of the model on validation data set is 0.037744

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 30

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op8 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op8, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op8.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op8_submit.csv', index = False)
# Out:
# The training time of the model is: 20s
# The rmspe of the model on validation data set is 0.051076

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 10

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op9 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op9, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op9.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op9_submit.csv', index = False)
# Out:
# The training time of the model is: 7s
# The rmspe of the model on validation data set is 0.299687

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample':0.5}

#减少迭代次数

num_round = 20

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op10 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op10, dval)

closed = (features_test_pd['Open'] == 0).values

dtest = xgb.DMatrix(features_test_pd)
sales_pred = model_op10.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op10_submit.csv', index = False)
# Out:
# The training time of the model is: 13s
# The rmspe of the model on validation data set is 0.108725

# %%
#设定参数，减小max_depth

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.5, 'colsample_bytree': 0.5}

#减少迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op11 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op11, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op11.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op11_submit.csv', index = False)
# Out:
# The training time of the model is: 36s
# The rmspe of the model on validation data set is 0.037294

# %%
#设定参数，增加参数colsample_bytree

param = {'max_depth': 3, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.5, 'colsample_bytree': 0.5}

#迭代次数

num_round = 20

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op12 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op12, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op12.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op12_submit.csv', index = False)
# Out:
# The training time of the model is: 8s
# The rmspe of the model on validation data set is 0.118661

# %%
#设定参数，增加参数colsample_bytree

param = {'max_depth': 10, 'eta': 0.1, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.5, 'colsample_bytree': 0.5}

#迭代次数

num_round = 20

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op13 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op13, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op13.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op13_submit.csv', index = False)
# Out:
# The training time of the model is: 24s
# The rmspe of the model on validation data set is 0.116131

# %%
#设定参数，增加参数colsample_bytree

param = {'max_depth': 10, 'eta': 0.01, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.8, 'colsample_bytree': 0.8}

#迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op14 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op14, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op14.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op14_submit.csv', index = False)
# Out:
# The training time of the model is: 168s
# The rmspe of the model on validation data set is 0.315542

# %%
#设定参数，增加参数colsample_bytree

param = {'max_depth': 10, 'eta': 0.01, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 2}

#迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op15 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op15, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op15.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op15_submit.csv', index = False)
# Out:
# The training time of the model is: 162s
# The rmspe of the model on validation data set is 0.315542

# %%
#设定参数

param = {'max_depth': 5, 'eta': 0.01, 'silent': 0, 'objective': 'reg:linear', 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 2}

#迭代次数

num_round = 100

#依然用全部数据训练
dtrain = xgb.DMatrix(X_train, label = y_train)
dval = xgb.DMatrix(X_val, label = y_val)

#训练并打分
model_op16 = train_op(param, dtrain, num_round, rmspe_feval)
score(model_op16, dval)

closed = (features_test_pd['Open'] == 0).values

sales_pred = model_op16.predict(dtest)
sales_pred = np.exp(sales_pred) - 1
sales_pred[closed] = 0
submission_op = pd.DataFrame({'Id':test_data['Id'], 'Sales': sales_pred})
submission_op = submission_op.sort_values(by = 'Id')
submission_op.to_csv('xgboost_op16_submit.csv', index = False)
# Out:
# The training time of the model is: 76s
# The rmspe of the model on validation data set is 0.315684

# %% [markdown]
# 效果一直不理想，重开一个重新处理一下
